# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/cep/base_88.csv', encoding='latin-1', sep=',')

# %%
df.head()
# Out:
#    Unnamed: 0  secu      pond  region     nom_region  zona_u_r  gse  encuesta  \
# 0           1   139  0.970111      13  METROPOLITANA         1    3        88
# 1           2   140  1.616056      13  METROPOLITANA         1    3        88
# 2           3   139  1.523786      13  METROPOLITANA         1    3        88
# 3           4    71  1.066547       7          MAULE         1    3        88
# 4           5    85  1.518043       8         BIOBÍO         1    3        88
#
#    encuesta_a  encuesta_m  ...  info_hogar_34_b  info_hogar_34_c info_hogar_1  \
# 0        2022          11  ...              2.0              2.0          6.0
# 1        2022          11  ...              2.0              2.0          6.0
# 2        2022          11  ...              1.0              2.0          6.0
# 3        2022          11  ...              2.0              1.0          4.0
# 4        2022          11  ...              2.0              2.0          1.0
#
# ...
